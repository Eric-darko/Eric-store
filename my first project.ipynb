# %%
print("hello world")
# Out:
# hello world

# %%
print("my name is eric")
# Out:
# my name is eric

# %%
x=6
y=7
print(y)
# Out:
# 7

# %%
print(x+y)
# Out:
# 13

# %%
print(x*y)
# Out:
# 42

# %%
print(x/y)
# Out:
# 0.8571428571428571

# %%
z=x*y
print(z)
# Out:
# 42

# %%
print("sum of x any y =",x+y)
# Out:
# sum of x any y = 13

# %%
print("the values of x and y are",x,"and",y)
# Out:
# the values of x and y are 6 and 7

# %%
print("multiplication of x & y =",z)
# Out:
# multiplication of x & y = 42
